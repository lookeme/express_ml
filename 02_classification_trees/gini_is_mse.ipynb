# %%
from matplotlib import pyplot as plt
import numpy as np

# %%
p = np.arange(0, 1, 0.01)
q = (1-p)

print(q)
entropy = - (p * np.log2(p + 0.001) + q * np.log2(q + 0.001))

gini = p*q + q*p

misclassified = np.where(p < q, p, q)

MSE = p*q*q + q*p*p

plt.plot(p, entropy/entropy.max(), label='entropy')
plt.plot(p, gini/gini.max(), label='gini')
plt.plot(p, misclassified/misclassified.max(), label='misclassified')
plt.plot(p, MSE/MSE.max(), label='MSE')

plt.legend()
plt.xlabel('p')
plt.ylabel('error')
plt.show()
# Out:
# [1.   0.99 0.98 0.97 0.96 0.95 0.94 0.93 0.92 0.91 0.9  0.89 0.88 0.87
#  0.86 0.85 0.84 0.83 0.82 0.81 0.8  0.79 0.78 0.77 0.76 0.75 0.74 0.73
#  0.72 0.71 0.7  0.69 0.68 0.67 0.66 0.65 0.64 0.63 0.62 0.61 0.6  0.59
#  0.58 0.57 0.56 0.55 0.54 0.53 0.52 0.51 0.5  0.49 0.48 0.47 0.46 0.45
#  0.44 0.43 0.42 0.41 0.4  0.39 0.38 0.37 0.36 0.35 0.34 0.33 0.32 0.31
#  0.3  0.29 0.28 0.27 0.26 0.25 0.24 0.23 0.22 0.21 0.2  0.19 0.18 0.17
#  0.16 0.15 0.14 0.13 0.12 0.11 0.1  0.09 0.08 0.07 0.06 0.05 0.04 0.03
#  0.02 0.01]

# %%
np.seed = 7
train_data = np.random.normal(size=(100, 2))
train_labels = np.zeros(100)

# добавляем второй класс
train_data = np.r_[train_data, np.random.normal(size=(100, 2), loc=2)]
train_labels = np.r_[train_labels, np.ones(100)]

print(train_data[:, 0])

plt.rcParams['figure.figsize'] = (10,8)
plt.scatter(train_data[:, 0], train_data[:, 1], c=train_labels, s=100, 
cmap='autumn', edgecolors='black', linewidth=1.5);
plt.plot(range(-2,5), range(4,-3,-1));
# Out:
# [ 5.83454234e-01 -1.46556294e+00  3.20891519e-01 -1.39598016e+00
#  -4.48352126e-01 -2.43485365e+00 -2.12569844e+00 -3.50126370e-01
#  -1.64873108e-01 -2.21628738e-01 -6.90447459e-02 -7.26577816e-01
#   6.75074406e-01  4.66306851e-01  5.88426664e-01  2.45047614e-01
#   7.48403940e-01  3.56000658e-01  2.11221824e-01  2.16626118e-02
#   2.28337451e-02  5.53457631e-01 -6.76910077e-01 -7.49176269e-01
#   3.08716605e-02  2.27426731e-01 -1.31745505e+00 -1.98018126e-01
#  -5.87367433e-01  3.32328664e-01 -1.74702364e+00 -2.73525935e-01
#   8.59667124e-02 -1.44041834e+00 -5.39179827e-01  1.19569582e+00
#   1.24279159e+00 -1.65404788e+00 -1.14748875e+00 -4.26179259e-01
#   1.57696344e+00 -1.31688038e+00 -2.30069240e+00 -4.56195114e-02
#  -3.33527729e-01 -1.25311440e+00 -3.90251219e-01  8.46370680e-01
#  -4.25591299e-01  5.72863680e-01 -1.62746248e+00  2.69731627e+00
